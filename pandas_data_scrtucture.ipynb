# %%
import pandas as pd
import numpy as np
import numpy.random as rd
import matplotlib.pyplot as plt
from IPython import display
import random

#Series array de una sola dimencion  s = pd.Series(data, index=index)
#series desde un arreglo  index , datos random 5
s=pd.Series(np.random.randn(5),index=['a','b','c','d','e'])
print(s)
 
# mostrando index
s.index

# series sin index numerical default
numeric=pd.Series(np.random.randn(5))
print('-----------------numeric')
print(numeric)

# creating series dewsde dicionarios
d = {'b' : 1, 'a' : 0, 'c' : 2}
dicio=pd.Series(d)

print('-----------------dicio')
print(dicio)

#crear series desde dic
dicciona=pd.Series(d,index=['b','c','d','a'])
print('-----------------dicciona')
print(dicciona)

#valor escalar con index 
escalar=pd.Series(5,index=['a','b','c','d','e'])
print('-----------------escalar')
print(escalar)


#Series ndarray-like

s[0]
#printing primeros 3 resultados
print('-----------------s[:3]')
print(s[:3])

# todos los calores d s que seam mayor que la media
sm=s[s>s.median()]
print('-----------------sm')
print(sm)

# calculando el exponencial de todos los elementos de s

expon=np.exp(s)
print('-----------------exponencial')
print(expon)

# get and set values from series
s['a']
print('-----------------')
print(s)
setv=s['e']=12
print(
    setv
)
print('-----------------s con set value [e]=12')
print(s)
print('-----------------e in s')
print('e' in s)

print('-----------------f in s')
print('f' in s)

# si no hay clave 
#s['f']
#fail

#retornar nulo  si no hay una llacve
s.get('F')
s.get('f',np.nan)

#ponerle nombres a las series con atrributo nombre

s=pd.Series(np.random.randn(5),name='ALGO')

print(s.name)

# rename series , new > 0.18 veresion

s2=s.rename('algo_diferente')
print(s2.name)
# Out:
# a   -1.327811
# b   -1.662606
# c   -0.074631
# d   -0.709518
# e   -0.329581
# dtype: float64
# -----------------numeric
# 0    1.736192
# 1   -0.513737
# 2   -0.967623
# 3   -0.159338
# 4   -0.217284
# dtype: float64
# -----------------dicio
# b    1
# a    0
# c    2
# dtype: int64
# -----------------dicciona
# b    1.0
# c    2.0
# d    NaN
# a    0.0
# dtype: float64
# -----------------escalar
# a    5
# b    5
# c    5
# d    5
# e    5
# dtype: int64
# -----------------s[:3]
# a   -1.327811
# b   -1.662606
# c   -0.074631
# dtype: float64
# -----------------sm
# c   -0.074631
# e   -0.329581
# dtype: float64
# -----------------exponencial
# a    0.265057
# b    0.189644
# c    0.928086
# d    0.491881
# e    0.719225
# dtype: float64
# -----------------
# a   -1.327811
# b   -1.662606
# c   -0.074631
# d   -0.709518
# e   -0.329581
# dtype: float64
# 12
# -----------------s con set value [e]=12
# a    -1.327811
# b    -1.662606
# c    -0.074631
# d    -0.709518
# ...
