# %%
import pandas as pd
import numpy as np
import numpy.random as rd
import matplotlib.pyplot as plt
from IPython import display
import random

s=pd.Series([1,2,34,59,75,np.nan,88,25,2])
#print(s)

dates = pd.date_range('20130101',periods=8)
print(dates)

df= pd.DataFrame(np.random.randn(8,4),index=dates,columns=list('ABCD'))
print (df)

df2= pd.DataFrame({
    'A':1.,
    'B':pd.Timestamp('20131010'),
    'C':np.array([3]*4,dtype='int64'),
    'D':pd.Series(1,index=list(range(4)),dtype='float32'),
    'F':'foo'


})
print (df2)

print (df2.dtypes)

print (df.head())
## retorna las ultima n lineas
print (df.tail(3))

print ('#')
print (df.index)
### columnas
print ('#')
print (df.columns)


### Resumen excluye los elementos nan
print ('#')
print (df.describe())

### Traspuesta matriz
print ('#')
print (df.T)

### Traspuesta matriz
print ('#')
#axis 1 order index
print (df.sort_index(axis=1,ascending=False))
print ('#axis 0') # order rows
print (df.sort_index(axis=0,ascending=False))


print ('#Sorrt values by colum') #
#print (df.sort_values(by='B')
print ('#show colum A') #
print (df['A'])
###
print ('#show  por rango [0:5] filas') #
print (df[0:6])

# muetsra la primera fila de todas las columnas
print ('# muetsra la primera fila de todas las columnas') #
#df.loc[dates[0]]

# muestra multibles filas por columnas
print ('# muestra multibles filas por columnas') #
#df.loc[:,['A','B']]

# muestra columna a y b que este entre esas fechas
#df.loc['20130102':'20130104',['A','B']]

# musrtea columna a y b que sea de esa fecha
#df.loc['20130102',['A','B']]


# valor escalar
print(df.loc[dates[0],'A'])

# df.iloc[3:5,0:2]
#df.iloc[[1,2,4],[0,2]]
#df.iloc[1:3,:]
#df.iloc[:,1:3]
#df.iloc[1,1]
#df.iat[1,1]
#    ##

# df.iloc[3]
#todas las filas donde  el valor de la columna a sea mayor que  0
print ('#todas las filas donde  el valor de la columna a sea mayor que  0') #
print (df[df.A>0])

print ('#todas las filas donde  el valor sea mayor que  0') #
print (df[df > 0])

df3 = df.copy()
#add valores y columna
df3['E'] = ['one', 'one','two','three','four','three','7',8]
print(df3)
print ('#crea una matris con lo valores q cumplen la condicion') #
#crea una matris con lo valores q cumplen la condicion
print (df3[df3['E'].isin(['two','7'])])

print ('#muestra  q filas cumplen la condicion') #
#crea una matris con lo valores q cumplen la condicion
print (df3['E'].isin(['two','7']))
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06', '2013-01-07', '2013-01-08'],
#               dtype='datetime64[ns]', freq='D')
#                    A         B         C         D
# 2013-01-01  0.389336  1.005424 -0.884701  0.219292
# 2013-01-02  0.070910 -1.193415  1.304422  1.585861
# 2013-01-03  0.278109  0.920426 -2.431137  1.673515
# 2013-01-04 -1.943047  0.813255  0.159711  0.528972
# 2013-01-05  0.460375  0.227538 -0.220114  1.771266
# 2013-01-06 -0.666867  0.361506 -1.909232 -1.233527
# 2013-01-07  1.443690  0.245869 -0.192631  0.461129
# 2013-01-08 -0.144740 -0.857513 -1.672661  1.938538
#      A          B  C    D    F
# 0  1.0 2013-10-10  3  1.0  foo
# 1  1.0 2013-10-10  3  1.0  foo
# 2  1.0 2013-10-10  3  1.0  foo
# 3  1.0 2013-10-10  3  1.0  foo
# A           float64
# B    datetime64[ns]
# C             int64
# D           float32
# F            object
# dtype: object
# ...
